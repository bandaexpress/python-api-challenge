# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping...Error:{e}")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | nova sintra
# Processing Record 3 of Set 1 | udachny
# Processing Record 4 of Set 1 | wailua homesteads
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | badger
# Processing Record 9 of Set 1 | gadzhiyevo
# Processing Record 10 of Set 1 | freetown
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | stanley
# Processing Record 13 of Set 1 | quelimane
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | kargil
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | swan hill
# Processing Record 19 of Set 1 | santo tome
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | tomatlan
# Processing Record 23 of Set 1 | manggar
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | prokhladnyy
# Processing Record 30 of Set 1 | kiunga
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | antsiranana
# Processing Record 33 of Set 1 | nelson
# Processing Record 34 of Set 1 | nuku'alofa
# Processing Record 35 of Set 1 | arinos
# Processing Record 36 of Set 1 | ponta delgada
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | karabash
# Processing Record 39 of Set 1 | blackmans bay
# Processing Record 40 of Set 1 | mudu
# Processing Record 41 of Set 1 | olonkinbyen
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | san antonio de pale
# Processing Record 46 of Set 1 | bavel
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | edinburgh of the seven seas
# Processing Record 49 of Set 1 | nova vicosa
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 0 of Set 2 | fort bragg
# Processing Record 1 of Set 2 | belyy yar
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | afaahiti
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | parabel'
# Processing Record 6 of Set 2 | fojnica
# Processing Record 7 of Set 2 | dunedin
# Processing Record 8 of Set 2 | cannonvale
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | cungus
# Processing Record 12 of Set 2 | al-`ula
# City not found. Skipping...Error:'coord'
# Processing Record 13 of Set 2 | grytviken
# Processing Record 14 of Set 2 | isfara
# Processing Record 15 of Set 2 | torghay
# Processing Record 16 of Set 2 | st. john's
# Processing Record 17 of Set 2 | tura
# Processing Record 18 of Set 2 | ust-nera
# Processing Record 19 of Set 2 | ad dabbah
# Processing Record 20 of Set 2 | inarajan village
# Processing Record 21 of Set 2 | ocean city
# Processing Record 22 of Set 2 | toga village
# City not found. Skipping...Error:'coord'
# Processing Record 23 of Set 2 | taroudant
# Processing Record 24 of Set 2 | alaghsas
# Processing Record 25 of Set 2 | nahiyat al fuhud
# Processing Record 26 of Set 2 | achinsk
# Processing Record 27 of Set 2 | yantarnyy
# Processing Record 28 of Set 2 | utrik
# Processing Record 29 of Set 2 | waingapu
# Processing Record 30 of Set 2 | wabag
# Processing Record 31 of Set 2 | saint cloud
# Processing Record 32 of Set 2 | papatowai
# Processing Record 33 of Set 2 | lihue
# Processing Record 34 of Set 2 | nuuk
# Processing Record 35 of Set 2 | raja
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | gangolli
# Processing Record 38 of Set 2 | kelso
# Processing Record 39 of Set 2 | west island
# Processing Record 40 of Set 2 | inirida
# Processing Record 41 of Set 2 | tolanaro
# Processing Record 42 of Set 2 | isangel
# Processing Record 43 of Set 2 | zharkent
# Processing Record 44 of Set 2 | spanish wells
# Processing Record 45 of Set 2 | luau
# Processing Record 46 of Set 2 | tshabong
# Processing Record 47 of Set 2 | taltal
# Processing Record 48 of Set 2 | isafjordur
# Processing Record 49 of Set 2 | mossel bay
# Processing Record 0 of Set 3 | port elizabeth
# Processing Record 1 of Set 3 | mong cai
# City not found. Skipping...Error:'coord'
# Processing Record 2 of Set 3 | san julian
# Processing Record 3 of Set 3 | pekan bahapal
# City not found. Skipping...Error:'coord'
# Processing Record 4 of Set 3 | klyuchi
# Processing Record 5 of Set 3 | taiohae
# City not found. Skipping...Error:'coord'
# Processing Record 6 of Set 3 | bayan nur
# City not found. Skipping...Error:'coord'
# Processing Record 7 of Set 3 | nurota
# Processing Record 8 of Set 3 | al bayda'
# Processing Record 9 of Set 3 | lusaka
# Processing Record 10 of Set 3 | la palma
# Processing Record 11 of Set 3 | rio grande
# Processing Record 12 of Set 3 | vadso
# Processing Record 13 of Set 3 | iqaluit
# Processing Record 14 of Set 3 | ryotsu-minato
# Processing Record 15 of Set 3 | ta`u
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | port mathurin
# Processing Record 20 of Set 3 | chibougamau
# Processing Record 21 of Set 3 | chonchi
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | qaqortoq
# Processing Record 24 of Set 3 | colares
# Processing Record 25 of Set 3 | lucapa
# Processing Record 26 of Set 3 | jinka
# Processing Record 27 of Set 3 | harper
# Processing Record 28 of Set 3 | faya-largeau
# Processing Record 29 of Set 3 | labytnangi
# Processing Record 30 of Set 3 | kuanda
# Processing Record 31 of Set 3 | tazovsky
# Processing Record 32 of Set 3 | dubbo
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | enewetak
# Processing Record 35 of Set 3 | olyokminsk
# Processing Record 36 of Set 3 | parkes
# Processing Record 37 of Set 3 | kailua-kona
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | acapulco de juarez
# Processing Record 40 of Set 3 | hawaiian paradise park
# Processing Record 41 of Set 3 | istgah-e rah ahan-e garmsar
# Processing Record 42 of Set 3 | mankera
# Processing Record 43 of Set 3 | puerto deseado
# Processing Record 44 of Set 3 | bolu
# Processing Record 45 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 3 | porto de moz
# Processing Record 47 of Set 3 | sambava
# Processing Record 48 of Set 3 | rabo de peixe
# Processing Record 49 of Set 3 | mek'ele
# Processing Record 0 of Set 4 | hanceville
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | viveiro
# Processing Record 3 of Set 4 | tarauaca
# Processing Record 4 of Set 4 | atafu village
# Processing Record 5 of Set 4 | angaur state
# Processing Record 6 of Set 4 | quellon
# Processing Record 7 of Set 4 | chamba
# Processing Record 8 of Set 4 | aral
# Processing Record 9 of Set 4 | dudinka
# Processing Record 10 of Set 4 | cogolin
# Processing Record 11 of Set 4 | aguas vermelhas
# Processing Record 12 of Set 4 | nikolayevsk-on-amure
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | slave lake
# Processing Record 15 of Set 4 | gemena
# Processing Record 16 of Set 4 | baise city
# Processing Record 17 of Set 4 | brookings
# Processing Record 18 of Set 4 | walvis bay
# Processing Record 19 of Set 4 | iskateley
# Processing Record 20 of Set 4 | mabaruma
# Processing Record 21 of Set 4 | fort st. john
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | zapala
# Processing Record 24 of Set 4 | recani
# Processing Record 25 of Set 4 | charters towers
# Processing Record 26 of Set 4 | winthrop harbor
# Processing Record 27 of Set 4 | bilibino
# Processing Record 28 of Set 4 | timbuktu
# Processing Record 29 of Set 4 | mejit
# Processing Record 30 of Set 4 | dzhetygara
# Processing Record 31 of Set 4 | nuriootpa
# Processing Record 32 of Set 4 | severo-yeniseyskiy
# Processing Record 33 of Set 4 | whitehorse
# Processing Record 34 of Set 4 | simanggang
# Processing Record 35 of Set 4 | punta arenas
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | aasiaat
# Processing Record 38 of Set 4 | las tablas
# Processing Record 39 of Set 4 | nagqu
# Processing Record 40 of Set 4 | los frentones
# Processing Record 41 of Set 4 | cruzeiro do sul
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | santa cruz
# Processing Record 44 of Set 4 | xinyuan
# Processing Record 45 of Set 4 | chernyshevskiy
# Processing Record 46 of Set 4 | vila franca do campo
# Processing Record 47 of Set 4 | robel
# Processing Record 48 of Set 4 | mandalgovi
# Processing Record 49 of Set 4 | riolandia
# Processing Record 0 of Set 5 | dondo
# Processing Record 1 of Set 5 | el hadjar
# Processing Record 2 of Set 5 | georgetown
# Processing Record 3 of Set 5 | puerto el triunfo
# Processing Record 4 of Set 5 | freeport
# Processing Record 5 of Set 5 | jamestown
# Processing Record 6 of Set 5 | maintirano
# Processing Record 7 of Set 5 | invercargill
# Processing Record 8 of Set 5 | kosciuszko national park
# City not found. Skipping...Error:'coord'
# Processing Record 9 of Set 5 | la passe
# Processing Record 10 of Set 5 | nar'yan-mar
# Processing Record 11 of Set 5 | tranovaho
# City not found. Skipping...Error:'coord'
# Processing Record 12 of Set 5 | san antonio del estrecho
# City not found. Skipping...Error:'coord'
# Processing Record 13 of Set 5 | 'ohonua
# City not found. Skipping...Error:'coord'
# Processing Record 14 of Set 5 | zheleznodorozhnyy
# Processing Record 15 of Set 5 | sosnovo-ozerskoye
# Processing Record 16 of Set 5 | clearwater
# Processing Record 17 of Set 5 | laojunmiao
# Processing Record 18 of Set 5 | usogorsk
# Processing Record 19 of Set 5 | kochubey
# Processing Record 20 of Set 5 | monteagudo
# Processing Record 21 of Set 5 | jianshui
# Processing Record 22 of Set 5 | boa vista
# Processing Record 23 of Set 5 | wladyslawowo
# Processing Record 24 of Set 5 | karachi
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | san luis de la loma
# Processing Record 27 of Set 5 | chicama
# Processing Record 28 of Set 5 | anahuac
# Processing Record 29 of Set 5 | bijawar
# Processing Record 30 of Set 5 | la'ie
# Processing Record 31 of Set 5 | amga
# Processing Record 32 of Set 5 | mugia
# Processing Record 33 of Set 5 | ribeira brava
# Processing Record 34 of Set 5 | zaozersk
# Processing Record 35 of Set 5 | inari
# Processing Record 36 of Set 5 | ad darb
# Processing Record 37 of Set 5 | mil'kovo
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | porsgrunn
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | akkus
# Processing Record 42 of Set 5 | crane
# Processing Record 43 of Set 5 | pacific grove
# Processing Record 44 of Set 5 | ponmana
# City not found. Skipping...Error:'coord'
# Processing Record 45 of Set 5 | sakaiminato
# Processing Record 46 of Set 5 | port alfred
# Processing Record 47 of Set 5 | margaret river
# Processing Record 48 of Set 5 | saint-jean-de-monts
# Processing Record 49 of Set 5 | ba
# City not found. Skipping...Error:'coord'
# Processing Record 0 of Set 6 | serowe
# Processing Record 1 of Set 6 | obo
# Processing Record 2 of Set 6 | hadibu
# Processing Record 3 of Set 6 | raduzhny
# Processing Record 4 of Set 6 | magistral'nyy
# Processing Record 5 of Set 6 | teguise
# Processing Record 6 of Set 6 | mitu
# Processing Record 7 of Set 6 | norrtalje
# Processing Record 8 of Set 6 | ludus
# Processing Record 9 of Set 6 | nouadhibou
# Processing Record 10 of Set 6 | rongelap
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | mountain home
# Processing Record 13 of Set 6 | oistins
# Processing Record 14 of Set 6 | queenstown
# Processing Record 15 of Set 6 | newman
# Processing Record 16 of Set 6 | ma'ili
# Processing Record 17 of Set 6 | polyarnyy
# Processing Record 18 of Set 6 | jincheng
# Processing Record 19 of Set 6 | jiwani
# Processing Record 20 of Set 6 | akureyri
# Processing Record 21 of Set 6 | port blair
# Processing Record 22 of Set 6 | fort mcmurray
# Processing Record 23 of Set 6 | chebarkul'
# Processing Record 24 of Set 6 | thinadhoo
# Processing Record 25 of Set 6 | alotau
# City not found. Skipping...Error:'coord'
# Processing Record 26 of Set 6 | kill devil hills
# Processing Record 27 of Set 6 | katsuren-haebaru
# Processing Record 28 of Set 6 | keflavik
# Processing Record 29 of Set 6 | umm kaddadah
# Processing Record 30 of Set 6 | boda
# Processing Record 31 of Set 6 | rawson
# Processing Record 32 of Set 6 | kadugli
# Processing Record 33 of Set 6 | al hudaydah
# Processing Record 34 of Set 6 | vingt cinq
# City not found. Skipping...Error:'coord'
# Processing Record 35 of Set 6 | kitakata
# Processing Record 36 of Set 6 | mount pearl
# Processing Record 37 of Set 6 | leo
# Processing Record 38 of Set 6 | miri
# Processing Record 39 of Set 6 | miyaly
# Processing Record 40 of Set 6 | labuan lombok
# City not found. Skipping...Error:'coord'
# Processing Record 41 of Set 6 | jiagedaqi
# Processing Record 42 of Set 6 | nadi
# Processing Record 43 of Set 6 | dongola
# Processing Record 44 of Set 6 | oriximina
# Processing Record 45 of Set 6 | urumqi
# Processing Record 46 of Set 6 | key west
# Processing Record 47 of Set 6 | mantua
# Processing Record 48 of Set 6 | taupo
# Processing Record 49 of Set 6 | magadan
# Processing Record 0 of Set 7 | bac lieu
# Processing Record 1 of Set 7 | novoul'yanovsk
# Processing Record 2 of Set 7 | porto novo
# Processing Record 3 of Set 7 | taulaga
# Processing Record 4 of Set 7 | launceston
# Processing Record 5 of Set 7 | muynoq
# Processing Record 6 of Set 7 | haiku-pauwela
# Processing Record 7 of Set 7 | luganville
# Processing Record 8 of Set 7 | lazaro cardenas
# Processing Record 9 of Set 7 | patacamaya
# Processing Record 10 of Set 7 | bel ombre
# Processing Record 11 of Set 7 | la punta
# Processing Record 12 of Set 7 | bargara
# City not found. Skipping...Error:'coord'
# Processing Record 13 of Set 7 | maubara
# City not found. Skipping...Error:'coord'
# Processing Record 14 of Set 7 | jijel
# Processing Record 15 of Set 7 | ambon
# Processing Record 16 of Set 7 | arawa
# Processing Record 17 of Set 7 | labrador city
# Processing Record 18 of Set 7 | wynyard
# Processing Record 19 of Set 7 | dabakala
# Processing Record 20 of Set 7 | swakopmund
# Processing Record 21 of Set 7 | akhmet'a
# Processing Record 22 of Set 7 | montepuez
# Processing Record 23 of Set 7 | cururupu
# Processing Record 24 of Set 7 | daru
# Processing Record 25 of Set 7 | visakhapatnam
# Processing Record 26 of Set 7 | wanning
# Processing Record 27 of Set 7 | la mira
# Processing Record 28 of Set 7 | vilyuchinsk
# Processing Record 29 of Set 7 | bodo
# Processing Record 30 of Set 7 | laguna paiva
# Processing Record 31 of Set 7 | xilin hot
# Processing Record 32 of Set 7 | constantia
# Processing Record 33 of Set 7 | remire-montjoly
# Processing Record 34 of Set 7 | kaisiadorys
# Processing Record 35 of Set 7 | mount isa
# Processing Record 36 of Set 7 | khandyga
# Processing Record 37 of Set 7 | kingston
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | lycksele
# Processing Record 40 of Set 7 | kameshkovo
# Processing Record 41 of Set 7 | isla vista
# Processing Record 42 of Set 7 | callao
# Processing Record 43 of Set 7 | mermoz boabab
# Processing Record 44 of Set 7 | orosei
# Processing Record 45 of Set 7 | sinabang
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | antofagasta
# Processing Record 48 of Set 7 | nevada
# Processing Record 49 of Set 7 | saipan
# Processing Record 0 of Set 8 | hamilton
# Processing Record 1 of Set 8 | armacao de buzios
# Processing Record 2 of Set 8 | kasama
# Processing Record 3 of Set 8 | khalifah a city
# City not found. Skipping...Error:'coord'
# Processing Record 4 of Set 8 | shirbin
# Processing Record 5 of Set 8 | cole harbour
# Processing Record 6 of Set 8 | susuman
# Processing Record 7 of Set 8 | mokolo
# Processing Record 8 of Set 8 | jean-rabel
# Processing Record 9 of Set 8 | tuy hoa
# Processing Record 10 of Set 8 | timimoun
# Processing Record 11 of Set 8 | tamanrasset
# Processing Record 12 of Set 8 | vastervik
# City not found. Skipping...Error:'coord'
# Processing Record 13 of Set 8 | smithers
# Processing Record 14 of Set 8 | cumaribo
# City not found. Skipping...Error:'coord'
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | nantucket
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | wuwei
# Processing Record 19 of Set 8 | carutapera
# Processing Record 20 of Set 8 | laguna
# Processing Record 21 of Set 8 | krasnapollye
# Processing Record 22 of Set 8 | aracataca
# Processing Record 23 of Set 8 | biltine
# Processing Record 24 of Set 8 | kayangel
# Processing Record 25 of Set 8 | santa vitoria do palmar
# Processing Record 26 of Set 8 | tugulym
# Processing Record 27 of Set 8 | pathein
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | happy valley-goose bay
# Processing Record 31 of Set 8 | fada
# Processing Record 32 of Set 8 | byakabanda
# Processing Record 33 of Set 8 | trincomalee
# Processing Record 34 of Set 8 | ambodifotatra
# Processing Record 35 of Set 8 | chaparral
# Processing Record 36 of Set 8 | hilo
# Processing Record 37 of Set 8 | bubaque
# Processing Record 38 of Set 8 | marshall
# Processing Record 39 of Set 8 | sao gabriel da cachoeira
# Processing Record 40 of Set 8 | gargalianoi
# Processing Record 41 of Set 8 | okha
# Processing Record 42 of Set 8 | eirunepe
# Processing Record 43 of Set 8 | magdagachi
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | vorgashor
# Processing Record 46 of Set 8 | shimoda
# Processing Record 47 of Set 8 | saint-pierre-d'oleron
# City not found. Skipping...Error:'coord'
# Processing Record 48 of Set 8 | santa isabel
# Processing Record 49 of Set 8 | fortuna
# Processing Record 0 of Set 9 | pemangkat
# Processing Record 1 of Set 9 | ain sukhna
# Processing Record 2 of Set 9 | igarka
# Processing Record 3 of Set 9 | sanguem
# Processing Record 4 of Set 9 | cova figueira
# Processing Record 5 of Set 9 | zakynthos
# Processing Record 6 of Set 9 | xiahu
# Processing Record 7 of Set 9 | al kharijah
# Processing Record 8 of Set 9 | banda aceh
# Processing Record 9 of Set 9 | island harbour
# Processing Record 10 of Set 9 | berezovyy
# Processing Record 11 of Set 9 | keren
# Processing Record 12 of Set 9 | cargados carajos
# City not found. Skipping...Error:'coord'
# Processing Record 13 of Set 9 | cable beach
# City not found. Skipping...Error:'coord'
# Processing Record 14 of Set 9 | morinville
# Processing Record 15 of Set 9 | rye
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | soio
# Processing Record 18 of Set 9 | luanda
# Processing Record 19 of Set 9 | yinchuan
# Processing Record 20 of Set 9 | lms
# City not found. Skipping...Error:'coord'
# Processing Record 21 of Set 9 | devadanappatti
# Processing Record 22 of Set 9 | axim
# Processing Record 23 of Set 9 | puerto san carlos
# City not found. Skipping...Error:'coord'
# Processing Record 24 of Set 9 | kununurra
# Processing Record 25 of Set 9 | aldan
# Processing Record 26 of Set 9 | payakumbuh
# Processing Record 27 of Set 9 | maine soroa
# Processing Record 28 of Set 9 | dwarka
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | pangkalanbuun
# Processing Record 31 of Set 9 | usinsk
# Processing Record 32 of Set 9 | brush
# Processing Record 33 of Set 9 | pandan
# Processing Record 34 of Set 9 | goundam
# Processing Record 35 of Set 9 | manokwari
# Processing Record 36 of Set 9 | sorong
# Processing Record 37 of Set 9 | bayramaly
# Processing Record 38 of Set 9 | vallenar
# Processing Record 39 of Set 9 | uribia
# Processing Record 40 of Set 9 | bikenibeu village
# Processing Record 41 of Set 9 | masterton
# Processing Record 42 of Set 9 | ristiina
# Processing Record 43 of Set 9 | kone
# Processing Record 44 of Set 9 | mumford
# Processing Record 45 of Set 9 | arraial do cabo
# Processing Record 46 of Set 9 | nicoya
# Processing Record 47 of Set 9 | new norfolk
# Processing Record 48 of Set 9 | alofi
# Processing Record 49 of Set 9 | xuddur
# Processing Record 0 of Set 10 | lapaha
# City not found. Skipping...Error:'coord'
# Processing Record 1 of Set 10 | marabba
# Processing Record 2 of Set 10 | postmasburg
# City not found. Skipping...Error:'coord'
# Processing Record 3 of Set 10 | balma
# Processing Record 4 of Set 10 | sungai penuh
# Processing Record 5 of Set 10 | papao
# Processing Record 6 of Set 10 | kapuskasing
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | yungay
# Processing Record 9 of Set 10 | tuscaloosa
# Processing Record 10 of Set 10 | padangsidempuan
# Processing Record 11 of Set 10 | vegreville
# Processing Record 12 of Set 10 | manado
# Processing Record 13 of Set 10 | basco
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | sainte-marie
# Processing Record 16 of Set 10 | illizi
# Processing Record 17 of Set 10 | panama city beach
# Processing Record 18 of Set 10 | dalandzadgad
# Processing Record 19 of Set 10 | jabat
# Processing Record 20 of Set 10 | camana
# Processing Record 21 of Set 10 | yilan
# Processing Record 22 of Set 10 | el dorado
# Processing Record 23 of Set 10 | vakarai
# Processing Record 24 of Set 10 | pennagaram
# Processing Record 25 of Set 10 | el calafate
# Processing Record 26 of Set 10 | spring valley
# Processing Record 27 of Set 10 | mayakonda
# Processing Record 28 of Set 10 | flying fish cove
# Processing Record 29 of Set 10 | fale old settlement
# Processing Record 30 of Set 10 | madison
# Processing Record 31 of Set 10 | quang ngai
# Processing Record 32 of Set 10 | tual
# Processing Record 33 of Set 10 | ambo
# Processing Record 34 of Set 10 | kronach
# Processing Record 35 of Set 10 | geraldton
# Processing Record 36 of Set 10 | colipapa
# Processing Record 37 of Set 10 | saquarema
# Processing Record 38 of Set 10 | ujae
# Processing Record 39 of Set 10 | forster
# Processing Record 40 of Set 10 | sao francisco do sul
# Processing Record 41 of Set 10 | tobi village
# City not found. Skipping...Error:'coord'
# Processing Record 42 of Set 10 | carsamba
# Processing Record 43 of Set 10 | powell river
# Processing Record 44 of Set 10 | taikang
# Processing Record 45 of Set 10 | fuvahmulah
# City not found. Skipping...Error:'coord'
# Processing Record 46 of Set 10 | santiago de cao
# Processing Record 47 of Set 10 | pitimbu
# Processing Record 48 of Set 10 | turuntayevo
# Processing Record 49 of Set 10 | sishilichengzi
# City not found. Skipping...Error:'coord'
# Processing Record 0 of Set 11 | bonthe
# Processing Record 1 of Set 11 | mersa matruh
# Processing Record 2 of Set 11 | bejubang dua
# City not found. Skipping...Error:'coord'
# Processing Record 3 of Set 11 | port douglas
# Processing Record 4 of Set 11 | kuqa
# Processing Record 5 of Set 11 | minas de marcona
# Processing Record 6 of Set 11 | togur
# Processing Record 7 of Set 11 | yoloten
# Processing Record 8 of Set 11 | howard springs
# Processing Record 9 of Set 11 | bahia blanca
# Processing Record 10 of Set 11 | keningau
# Processing Record 11 of Set 11 | puerto princesa
# Processing Record 12 of Set 11 | road town
# Processing Record 13 of Set 11 | george town
# Processing Record 14 of Set 11 | tanjung pandan
# Processing Record 15 of Set 11 | mansoa
# Processing Record 16 of Set 11 | xai-xai
# Processing Record 17 of Set 11 | inhambane
# Processing Record 18 of Set 11 | puerto baquerizo moreno
# Processing Record 19 of Set 11 | bayanhongor
# Processing Record 20 of Set 11 | gisborne
# Processing Record 21 of Set 11 | thiers
# Processing Record 22 of Set 11 | lata
# Processing Record 23 of Set 11 | bamboo flat
# Processing Record 24 of Set 11 | verkhnevilyuysk
# Processing Record 25 of Set 11 | timaru
# Processing Record 26 of Set 11 | pico truncado
# Processing Record 27 of Set 11 | ivdel'
# Processing Record 28 of Set 11 | calvinia
# Processing Record 29 of Set 11 | devinuwara
# City not found. Skipping...Error:'coord'
# Processing Record 30 of Set 11 | huatabampo
# Processing Record 31 of Set 11 | sao felix do xingu
# Processing Record 32 of Set 11 | formosa do rio preto
# Processing Record 33 of Set 11 | jiuquan
# Processing Record 34 of Set 11 | sonsorol village
# City not found. Skipping...Error:'coord'
# Processing Record 35 of Set 11 | ciudad lazaro cardenas
# Processing Record 36 of Set 11 | zbarazh
# Processing Record 37 of Set 11 | haiphong
# Processing Record 38 of Set 11 | yangor
# City not found. Skipping...Error:'coord'
# Processing Record 39 of Set 11 | nakamura
# Processing Record 40 of Set 11 | dhidhdhoo
# Processing Record 41 of Set 11 | cox's bazar
# Processing Record 42 of Set 11 | volokolamsk
# Processing Record 43 of Set 11 | santa elena de uairen
# Processing Record 44 of Set 11 | weno
# Processing Record 45 of Set 11 | kuzovatovo
# Processing Record 46 of Set 11 | saint-francois
# Processing Record 47 of Set 11 | sungai raya
# Processing Record 48 of Set 11 | vega de alatorre
# Processing Record 49 of Set 11 | ouellah
# City not found. Skipping...Error:'coord'
# Processing Record 0 of Set 12 | yurimaguas
# Processing Record 1 of Set 12 | nemuro
# Processing Record 2 of Set 12 | danli
# Processing Record 3 of Set 12 | balurghat
# Processing Record 4 of Set 12 | fomboni
# Processing Record 5 of Set 12 | klaksvik
# Processing Record 6 of Set 12 | rumphi
# Processing Record 7 of Set 12 | caucete
# Processing Record 8 of Set 12 | meadow lake
# Processing Record 9 of Set 12 | mahina
# Processing Record 10 of Set 12 | harstad
# Processing Record 11 of Set 12 | quepos
# Processing Record 12 of Set 12 | tobelo
# Processing Record 13 of Set 12 | zhangye
# Processing Record 14 of Set 12 | horn
# Processing Record 15 of Set 12 | kalmunai
# Processing Record 16 of Set 12 | ocampo
# Processing Record 17 of Set 12 | arauco
# Processing Record 18 of Set 12 | sretensk
# Processing Record 19 of Set 12 | plesetsk
# Processing Record 20 of Set 12 | akom ii
# Processing Record 21 of Set 12 | lensk
# Processing Record 22 of Set 12 | caudete
# Processing Record 23 of Set 12 | ballina
# Processing Record 24 of Set 12 | bratsk
# Processing Record 25 of Set 12 | tyukhtet
# Processing Record 26 of Set 12 | emirgazi
# Processing Record 27 of Set 12 | valparaiso
# Processing Record 28 of Set 12 | at taj
# Processing Record 29 of Set 12 | gazipasa
# Processing Record 30 of Set 12 | shaowu
# Processing Record 31 of Set 12 | fisterra
# Processing Record 32 of Set 12 | attapeu
# Processing Record 33 of Set 12 | kapoeta
# Processing Record 34 of Set 12 | vazante
# Processing Record 35 of Set 12 | alvaraes
# Processing Record 36 of Set 12 | ytyk-kyuyel'
# City not found. Skipping...Error:'coord'
# Processing Record 37 of Set 12 | brits
# Processing Record 38 of Set 12 | ardestan
# Processing Record 39 of Set 12 | hohenems
# Processing Record 40 of Set 12 | dakhla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           cidreira -30.1811  -50.2056     25.60        84         100
# 1        nova sintra  14.8667  -24.7167     21.17        76         100
# 2            udachny  66.4167  112.4000    -25.31        75          99
# 3  wailua homesteads  22.0669 -159.3780     20.44        83          20
# 4          adamstown -25.0660 -130.1015     22.56        78          40
#
#    Wind Speed Country        Date
# 0        4.02      BR  1701967310
# 1        6.73      CV  1701967310
# 2        1.26      RU  1701967310
# 3        3.09      US  1701967310
# 4        4.88      PN  1701967310

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 cidreira -30.1811  -50.2056     25.60        84         100
# 1              nova sintra  14.8667  -24.7167     21.17        76         100
# 2                  udachny  66.4167  112.4000    -25.31        75          99
# 3        wailua homesteads  22.0669 -159.3780     20.44        83          20
# 4                adamstown -25.0660 -130.1015     22.56        78          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.02      BR  1701967310
# 1              6.73      CV  1701967310
# 2              1.26      RU  1701967310
# 3              3.09      US  1701967310
# 4              4.88      PN  1701967310

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker="o", facecolors="lightblue",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o", facecolors="lightblue",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o", facecolors="lightblue",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o", facecolors="lightblue",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x_data, y_data, x_label, y_label, title):

    # Calculate linear regression line
    slope, intercept = np.polyfit(x_data, y_data, 1)
    regression_line = slope * np.array(x_data) + intercept

    # Create scatter plot
    plt.scatter(x_data, y_data, marker="o", facecolors="blue", edgecolors="black", label="Data")

    # Plot the linear regression line
    plt.plot(x_data, regression_line, color="red", label="Linear Regression")

    # Set plot labels and title
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Add legend
    plt.legend()

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              nova sintra  14.8667  -24.7167     21.17        76         100
# 2                  udachny  66.4167  112.4000    -25.31        75          99
# 3        wailua homesteads  22.0669 -159.3780     20.44        83          20
# 7                   badger  64.8000 -147.5333    -17.05        83          20
# 8               gadzhiyevo  69.2551   33.3362    -16.65        98          39
#
#          Wind Speed Country        Date
# City_ID
# 1              6.73      CV  1701967310
# 2              1.26      RU  1701967310
# 3              3.09      US  1701967310
# 7              2.57      US  1701967310
# 8              6.05      RU  1701967311

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          cidreira -30.1811  -50.2056     25.60        84         100
# 4         adamstown -25.0660 -130.1015     22.56        78          40
# 5        codrington -38.2667  141.9667     16.65        53         100
# 6          waitangi -43.9535 -176.5597     12.12        91          40
# 10            ancud -41.8697  -73.8203     14.51        65          48
#
#          Wind Speed Country        Date
# City_ID
# 0              4.02      BR  1701967310
# 4              4.88      PN  1701967310
# 5              1.89      AU  1701967310
# 6              8.67      NZ  1701967310
# 10             3.83      CL  1701967311

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

[m, b, rvalue, pvalue, stderrr] = linregress(x_values, y_values)
regress_values = x_values * m + b
line_eq = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
plt.plot(x_values, regress_values, "r-")
plt.scatter(x_values, y_values)
plt.annotate(line_eq,(5.8,0.8), fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
